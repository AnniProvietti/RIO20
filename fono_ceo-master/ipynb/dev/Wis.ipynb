# %%
from wis import WisconsinPlayers

wis = WisconsinPlayers().file_demographics(date="2012", start_count=(100, 150))
# Out:
# 22
# 22
# 22
# 22
# [[[{'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 1, 'house': 'I_N_I', 'forma': False, 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:18:20.544361', 'marker': 'I_N_I', 'carta_resposta': 1}, {'categoria': 'cor', 'xpos': 0, 'cor': False, 'acertos': 0, 'outros': False, 'house': 'I_N_I', 'forma': False, 'numero': True, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:18:38.255857', 'marker': 'I_N_I', 'carta_resposta': 2}, {'categoria': 'cor', 'xpos': 0, 'cor': False, 'score': 1, 'acertos': 0, 'house': 'I_N_I', 'outros': False, 'numero': True, 'ypos': 0, 'player': 0, 'state': '', 'forma': False, 'result': 1, 'time': '2012-06-12 09:19:10.790718', 'marker': 'I_N_I', 'carta_resposta': 3}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 1, 'house': 'I_N_I', 'forma': False, 'outros': False, 'numero': True, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:19:15.295201', 'marker': 'I_N_I', 'carta_resposta': 4}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 2, 'outros': False, 'house': 'I_N_I', 'forma': True, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:19:52.532331', 'marker': 'I_N_I', 'carta_resposta': 5}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'score': 1, 'acertos': 3, 'house': 'I_N_I', 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'forma': True, 'result': 1, 'time': '2012-06-12 09:19:59.955758', 'marker': 'I_N_I', 'carta_resposta': 6}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 4, 'house': 'I_N_I', 'forma': False, 'outros': False, 'numero': True, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:16.661450', 'marker': 'I_N_I', 'carta_resposta': 7}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 5, 'outros': False, 'house': 'I_N_I', 'forma': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:22.428462', 'marker': 'I_N_I', 'carta_resposta': 8}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'score': 1, 'acertos': 6, 'house': 'I_N_I', 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'forma': False, 'result': 1, 'time': '2012-06-12 09:20:27.344131', 'marker': 'I_N_I', 'carta_resposta': 9}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 7, 'house': 'I_N_I', 'forma': False, 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:29.310650', 'marker': 'I_N_I', 'carta_resposta': 10}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 8, 'outros': False, 'house': 'I_N_I', 'forma': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:32.158120', 'marker': 'I_N_I', 'carta_resposta': 11}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'score': 1, 'acertos': 9, 'house': 'I_N_I', 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'forma': True, 'result': 1, 'time': '2012-06-12 09:20:34.389736', 'marker': 'I_N_I', 'carta_resposta': 12}, {'categoria': 'cor', 'xpos': 0, 'cor': True, 'acertos': 10, 'house': 'I_N_I', 'forma': False, 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:36.683622', 'marker': 'I_N_I', 'carta_resposta': 13}, {'categoria': 'forma', 'xpos': 0, 'cor': True, 'acertos': 0, 'outros': False, 'house': 'I_N_I', 'forma': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'score': 1, 'result': 1, 'time': '2012-06-12 09:20:38.943936', 'marker': 'I_N_I', 'carta_resposta': 14}, {'categoria': 'forma', 'xpos': 0, 'cor': True, 'score': 1, 'acertos': 0, 'house': 'I_N_I', 'outros': False, 'numero': False, 'ypos': 0, 'player': 0, 'state': '', 'forma': False, 'result': 1, 'time': '2012-06-12 09:20:43.580653', 'marker': 'I_ ...
# 806
# 22
# 22
# 22
# 22
# 22
#      ano1  idade1 sexo1                   starttime
# 0     1.0    17.0     M  2012-06-12 09:08:46.724058  \
# 1     1.0    17.0     M  2012-06-12 09:08:46.724058
# 2     1.0    17.0     M  2012-06-12 09:08:46.724058
# 3     1.0    17.0     M  2012-06-12 09:08:46.724058
# 4     8.0    15.0     M  2012-06-12 09:11:34.530941
# ..    ...     ...   ...                         ...
# 801   NaN     NaN   NaN                         NaN
# 802   NaN     NaN   NaN                         NaN
# 803   NaN     NaN   NaN                         NaN
# 804   NaN     NaN   NaN                         NaN
# 805   NaN     NaN   NaN                         NaN
#
#                         endtime tipoescola       name  maxlevel
# 0    2012-06-12 09:47:11.483625    publica  wisconsin       1.0  \
# 1    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 2    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 3    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 4    2012-06-12 09:44:46.414719    publica  wisconsin       1.0
# ..                          ...        ...        ...       ...
# 801                         NaN        NaN        NaN       NaN
# 802                         NaN        NaN        NaN       NaN
# 803                         NaN        NaN        NaN       NaN
# 804                         NaN        NaN        NaN       NaN
# 805                         NaN        NaN        NaN       NaN
#
#                            time  categoria  ...               0          1
# 0    2012-06-12 09:17:48.686460        3.0  ...  Carta resposta  Categoria  \
# 1    2012-06-12 09:27:44.234913        0.0  ...  Carta resposta  Categoria
# 2    2012-06-12 09:27:44.830229        0.0  ...  Carta resposta  Categoria
# 3    2012-06-12 09:40:48.291958        1.0  ...  Carta resposta  Categoria
# 4    2012-06-12 09:13:30.714343        0.0  ...  Carta resposta  Categoria
# ..                          ...        ...  ...             ...        ...
# 801                         NaN        NaN  ...             NaN        NaN
# 802                         NaN        NaN  ...             NaN        NaN
# 803                         NaN        NaN  ...             NaN        NaN
# 804                         NaN        NaN  ...             NaN        NaN
# 805                         NaN        NaN  ...             NaN        NaN
#
#            2    3      4       5       6          7
# 0    Acertos  Cor  Forma  Número  Outros  Data/Hora  \
# 1    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 2    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 3    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 4    Acertos  Cor  Forma  Número  Outros  Data/Hora
# ..       ...  ...    ...     ...     ...        ...
# 801      NaN  NaN    NaN     NaN     NaN        NaN
# 802      NaN  NaN    NaN     NaN     NaN        NaN
# 803      NaN  NaN    NaN     NaN     NaN        NaN
# 804      NaN  NaN    NaN     NaN     NaN        NaN
# 805      NaN  NaN    NaN     NaN     NaN        NaN
#
#                               0    0
# 0    2012-06-12 09:17:48.686547  1.0
# 1    2012-06-12 09:27:44.235001  1.0
# 2    2012-06-12 09:27:44.830315  1.0
# 3    2012-06-12 09:40:48.292047  1.0
# 4    2012-06-12 09:13:30.714435  1.0
# ..                          ...  ...
# 801                         NaN  NaN
# 802                         NaN  NaN
# 803                         NaN  NaN
# 804                         NaN  NaN
# 805                         NaN  NaN
#
# [806 rows x 46 columns]

# %%
import seaborn as sns


sns.catplot(x='tipoescola', y='score', data=wis)
# Out:
#      ano1  idade1 sexo1                   starttime
# 0     1.0    17.0     M  2012-06-12 09:08:46.724058  \
# 1     1.0    17.0     M  2012-06-12 09:08:46.724058
# 2     1.0    17.0     M  2012-06-12 09:08:46.724058
# 3     1.0    17.0     M  2012-06-12 09:08:46.724058
# 4     8.0    15.0     M  2012-06-12 09:11:34.530941
# ..    ...     ...   ...                         ...
# 801   NaN     NaN   NaN                         NaN
# 802   NaN     NaN   NaN                         NaN
# 803   NaN     NaN   NaN                         NaN
# 804   NaN     NaN   NaN                         NaN
# 805   NaN     NaN   NaN                         NaN
#
#                         endtime tipoescola       name  maxlevel
# 0    2012-06-12 09:47:11.483625    publica  wisconsin       1.0  \
# 1    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 2    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 3    2012-06-12 09:47:11.483625    publica  wisconsin       1.0
# 4    2012-06-12 09:44:46.414719    publica  wisconsin       1.0
# ..                          ...        ...        ...       ...
# 801                         NaN        NaN        NaN       NaN
# 802                         NaN        NaN        NaN       NaN
# 803                         NaN        NaN        NaN       NaN
# 804                         NaN        NaN        NaN       NaN
# 805                         NaN        NaN        NaN       NaN
#
#                            time  categoria  ...               0          1
# 0    2012-06-12 09:17:48.686460        3.0  ...  Carta resposta  Categoria  \
# 1    2012-06-12 09:27:44.234913        0.0  ...  Carta resposta  Categoria
# 2    2012-06-12 09:27:44.830229        0.0  ...  Carta resposta  Categoria
# 3    2012-06-12 09:40:48.291958        1.0  ...  Carta resposta  Categoria
# 4    2012-06-12 09:13:30.714343        0.0  ...  Carta resposta  Categoria
# ..                          ...        ...  ...             ...        ...
# 801                         NaN        NaN  ...             NaN        NaN
# 802                         NaN        NaN  ...             NaN        NaN
# 803                         NaN        NaN  ...             NaN        NaN
# 804                         NaN        NaN  ...             NaN        NaN
# 805                         NaN        NaN  ...             NaN        NaN
#
#            2    3      4       5       6          7
# 0    Acertos  Cor  Forma  Número  Outros  Data/Hora  \
# 1    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 2    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 3    Acertos  Cor  Forma  Número  Outros  Data/Hora
# 4    Acertos  Cor  Forma  Número  Outros  Data/Hora
# ..       ...  ...    ...     ...     ...        ...
# 801      NaN  NaN    NaN     NaN     NaN        NaN
# 802      NaN  NaN    NaN     NaN     NaN        NaN
# 803      NaN  NaN    NaN     NaN     NaN        NaN
# 804      NaN  NaN    NaN     NaN     NaN        NaN
# 805      NaN  NaN    NaN     NaN     NaN        NaN
#
#                               0    0
# 0    2012-06-12 09:17:48.686547  1.0
# 1    2012-06-12 09:27:44.235001  1.0
# 2    2012-06-12 09:27:44.830315  1.0
# 3    2012-06-12 09:40:48.292047  1.0
# 4    2012-06-12 09:13:30.714435  1.0
# ..                          ...  ...
# 801                         NaN  NaN
# 802                         NaN  NaN
# 803                         NaN  NaN
# 804                         NaN  NaN
# 805                         NaN  NaN
#
# [806 rows x 46 columns]

# %%
import seaborn as sns


sns.catplot(x='tipoescola', y='acertos', data=wis)
