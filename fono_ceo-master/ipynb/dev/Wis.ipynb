# %%
from wis import WisconsinPlayers

wis = WisconsinPlayers().file_demographics(date="2012", start_count=(100, 120))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23388/4185836823.py in <module>
#       1 from wis import WisconsinPlayers
#       2
# ----> 3 wis = WisconsinPlayers().file_demographics(date="2012", start_count=(100, 120))
#
# ~/Documentos/LABASE/RIO+/fono_ceo-master/ipynb/dev/wis.py in file_demographics(self, date, start_count, name)
#      60         one_player_markers = [goals["markers"] for y in reg for game in self.one_player(y)["games"] for goals in game["goal"]if game["name"] == "wisconsin"]
#      61
# ---> 62         one_player_headings = [game["goal"]["headings"] for y in reg for game in self.one_player(y)["games"] if game["name"] == "wisconsin"]
#      63
#      64         one_player_time = [goals["time"] for y in reg for game in self.one_player(y)["games"] for goals in game["goal"]if game["name"] == "wisconsin"]
#
# ...

# %%
import seaborn as sns


sns.catplot(x='tipoescola', y='score', data=wis)

# %%
import seaborn as sns


sns.catplot(x='tipoescola', y='acertos', data=wis)
